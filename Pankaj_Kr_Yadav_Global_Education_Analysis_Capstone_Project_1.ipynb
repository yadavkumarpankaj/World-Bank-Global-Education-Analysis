# %% [markdown]
# <a href="https://colab.research.google.com/github/yadavkumarpankaj/World-Bank-Global-Education-Analysis/blob/main/Pankaj_Kr_Yadav_Global_Education_Analysis_Capstone_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The World Bank EdStats All Indicator Query holds over 4,000 internationally comparable indicators that describe education access, progression, completion, literacy, teachers, population, and expenditures.The indicators cover the education cycle from pre-primary to vocational and tertiary education and also holds learning outcome data from international and regional learning assessments (e.g. PISA, TIMSS, PIRLS), equity data from household surveys, and projection/attainment data. </b>
#
# ## <b> Explore and analyze the data to identify variation of indicators across the globe, which countries are more alike and different. Feel free to add more extensive analyses and details.</b>

# %% [markdown]
# # **<u>My Team Member</u> :**
# ## Pankaj Kumar Yadav (pankajkumaryadav1500420@gmail.com), Er Mudita Garg (mudita.garg.99@gmail.com), Harshada Gore (harshada1442@gmail.com)

# %% [markdown]
# # **Steps of Exploratory Data Analysis (EDA)**

# %% [markdown]
# ### **Step 1. Connection with the Data**
#
# The World Bank Group is the largest financier of education in the developing world.
#
# Here, we are provided with 5 datasets about global education statistics.
#
# The World Bank EdStats All Indicator Query holds around 4,000 internationally comparable indicators that describe education access, progression, completion, literacy, teachers, population, and expenditures.
#
# Now, we need to **decode the set of experiences** to identify variations of indicators across the globe, which countries are more alike and different.
#
# At first, we import the libraries or functions for **making our journey easy** and then **get connected** to the set of experiences.

# %%
# Import packages
import pandas as pd
pd.get_option("display.max_columns")
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Mount your drive and read the csv file. Make sure you are using the correct file path
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Just Give the the path of the folder to access the all csv data files
path='/content/drive/MyDrive/AlmaBetter/capstone_project/data/'

# %%
#Now Let's read the csv data in various dataframes
df_EdStatsCountry = pd.read_csv(path+ "EdStatsCountry.csv")
df_EdStatsData = pd.read_csv(path + "EdStatsData.csv")
df_EdStatsSeries = pd.read_csv(path + "EdStatsSeries.csv")
df_EdStatsFootNote = pd.read_csv(path + "EdStatsFootNote.csv")
df_EdStatsCountry_Series = pd.read_csv(path + "EdStatsCountry-Series.csv")

# %% [markdown]
# ### **Step 2. let's analyse all of the Dataset one by one**
#
# Set of features are the way to reach final decoded experience or conclusions.
#
# As there is a huge no. of experiences, we cannot see the whole lot of experiences and therefore we find the features on the **df_Datahead, tail, info,describe,etc.**.

# %% [markdown]
# #### Let's see "EdStatsCountry.csv" data
# * contains list of all countries that are present in the data (total of 241 countries) - along with other features specific to the country like - Region, Income Group specific to the country etc

# %%
df_country = df_EdStatsCountry.copy()
# Let's see the shape of EdStatsCountry Data 
print('DataFrame Shape :' , df_country.shape)
# list of Cloumns Names of df_country
print(list(df_country.columns.values))
# Out:
# DataFrame Shape : (241, 32)
# ['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code', 'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code', 'National accounts base year', 'National accounts reference year', 'SNA price valuation', 'Lending category', 'Other groups', 'System of National Accounts', 'Alternative conversion factor', 'PPP survey year', 'Balance of Payments Manual in use', 'External debt Reporting status', 'System of trade', 'Government Accounting concept', 'IMF data dissemination standard', 'Latest population census', 'Latest household survey', 'Source of most recent Income and expenditure data', 'Vital registration complete', 'Latest agricultural census', 'Latest industrial data', 'Latest trade data', 'Latest water withdrawal data', 'Unnamed: 31']

# %%
df_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 32 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country Code                                       241 non-null    object
#  1   Short Name                                         241 non-null    object
#  2   Table Name                                         241 non-null    object
#  3   Long Name                                          241 non-null    object
#  4   2-alpha code                                       238 non-null    object
#  5   Currency Unit                                      215 non-null    object
#  6   Special Notes                                      145 non-null    object
#  7   Region                                             214 non-null    object
#  8   Income Group                                       214 non-null    object
# ...

# %%
#check top 5 rows
df_country.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
#check bottom 5 rows
df_country.tail()
# Out:
#     Country Code    Short Name    Table Name                 Long Name  \
# 236          XKX        Kosovo        Kosovo        Republic of Kosovo
# 237          YEM         Yemen   Yemen, Rep.         Republic of Yemen
# 238          ZAF  South Africa  South Africa  Republic of South Africa
# 239          ZMB        Zambia        Zambia        Republic of Zambia
# 240          ZWE      Zimbabwe      Zimbabwe      Republic of Zimbabwe
#
#     2-alpha code       Currency Unit  \
# 236          NaN                Euro
# 237           YE         Yemeni rial
# 238           ZA  South African rand
# 239           ZM  New Zambian kwacha
# 240           ZW         U.S. dollar
#
#                                          Special Notes  \
# 236  Kosovo became a World Bank member on June 29, ...
# 237  Based on official government statistics and In...
# 238  Fiscal year end: March 31; reporting period fo...
# 239  National accounts data have rebased to reflect...
# ...

# %%
#check describe
df_country.describe()
# Out:
#        National accounts reference year  Latest industrial data  \
# count                          32.00000              107.000000
# mean                         2001.53125             2008.102804
# std                             5.24856                2.616834
# min                          1987.00000             2000.000000
# 25%                          1996.75000             2007.500000
# 50%                          2002.00000             2009.000000
# 75%                          2005.00000             2010.000000
# max                          2012.00000             2010.000000
#
#        Latest trade data  Unnamed: 31
# count         185.000000          0.0
# mean         2010.994595          NaN
# std             2.569675          NaN
# min          1995.000000          NaN
# 25%          2011.000000          NaN
# 50%          2012.000000          NaN
# 75%          2012.000000          NaN
# max          2012.000000          NaN

# %% [markdown]
# #### Let's see "EdStatsData.csv" data
# * contains each country, with list of indicators (3665 unique indicators); contains measurement value for each indicator from years 1970 to 2017; from 2020 to 2100 - contains projections

# %%
df_data=df_EdStatsData.copy()
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %% [markdown]
# *  we can easily notice that 2010 has most amount of data about the indicators so we will prefer it as base year where we need a base year

# %%
df_data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Indicator Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#         1970       1971       1972       1973       1974      1975  ...  2060  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 1        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# 2        NaN        NaN        NaN        NaN        NaN       NaN  ...   NaN
# ...

# %%
df_data.tail()
# Out:
#        Country Name Country Code  \
# 886925     Zimbabwe          ZWE
# 886926     Zimbabwe          ZWE
# 886927     Zimbabwe          ZWE
# 886928     Zimbabwe          ZWE
# 886929     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 886925  Youth illiterate population, 15-24 years, male...
# 886926  Youth literacy rate, population 15-24 years, b...
# 886927  Youth literacy rate, population 15-24 years, f...
# 886928  Youth literacy rate, population 15-24 years, g...
# 886929  Youth literacy rate, population 15-24 years, m...
#
#               Indicator Code  1970  1971  1972  1973  1974  1975  ...  2060  \
# 886925      UIS.LP.AG15T24.M   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 886926     SE.ADT.1524.LT.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 886927  SE.ADT.1524.LT.FE.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 886928  SE.ADT.1524.LT.FM.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# ...

# %%
# Let's see the shape of df_EdSatatsDataData 
print('DataFrame Shape :' , df_data.shape)
# list of Cloumns Names of df_data
print(list(df_data.columns.values))
# Out:
# DataFrame Shape : (886930, 70)
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045', '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090', '2095', '2100', 'Unnamed: 69']

# %% [markdown]
# #### Let's see "EdStatsSeries.csv" data
# * contains list of all indicators and the definition of each indicator

# %%
# Let's see the info
df_EdStatsCountry_Series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613 entries, 0 to 612
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CountryCode  613 non-null    object
#  1   SeriesCode   613 non-null    object
#  2   DESCRIPTION  613 non-null    object
#  3   Unnamed: 3   0 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 19.3+ KB

# %%
# Let's see the shape of df_df_EdStatsCountry_Series Data 
print('DataFrame Shape :' , df_EdStatsCountry_Series.shape)
# list of Cloumns Names of df_df_EdStatsCountry_Series
print(list(df_EdStatsCountry_Series.columns.values))
# Out:
# DataFrame Shape : (613, 4)
# ['CountryCode', 'SeriesCode', 'DESCRIPTION', 'Unnamed: 3']

# %%
df_EdStatsCountry_Series.head()
# Out:
#   CountryCode         SeriesCode  \
# 0         ABW        SP.POP.TOTL
# 1         ABW        SP.POP.GROW
# 2         AFG        SP.POP.GROW
# 3         AFG  NY.GDP.PCAP.PP.CD
# 4         AFG        SP.POP.TOTL
#
#                                          DESCRIPTION  Unnamed: 3
# 0  Data sources : United Nations World Population...         NaN
# 1  Data sources: United Nations World Population ...         NaN
# 2  Data sources: United Nations World Population ...         NaN
# 3                 Estimates are based on regression.         NaN
# 4  Data sources : United Nations World Population...         NaN

# %%
df_EdStatsCountry_Series.tail()
# Out:
#     CountryCode   SeriesCode  \
# 608         ZAF  SP.POP.GROW
# 609         ZMB  SP.POP.GROW
# 610         ZMB  SP.POP.TOTL
# 611         ZWE  SP.POP.TOTL
# 612         ZWE  SP.POP.GROW
#
#                                            DESCRIPTION  Unnamed: 3
# 608  Data sources : Statistics South Africa, United...         NaN
# 609  Data sources: United Nations World Population ...         NaN
# 610  Data sources : United Nations World Population...         NaN
# 611  Data sources : United Nations World Population...         NaN
# 612  Data sources: United Nations World Population ...         NaN

# %% [markdown]
# #### Let's see "EdStatsFootNote.csv" data
# * It contains the estimations and uncertainty bounds for each year - looks like some years are missing

# %%
df_EdStatsFootNote.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643638 entries, 0 to 643637
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   CountryCode  643638 non-null  object
#  1   SeriesCode   643638 non-null  object
#  2   Year         643638 non-null  object
#  3   DESCRIPTION  643638 non-null  object
#  4   Unnamed: 4   0 non-null       float64
# dtypes: float64(1), object(4)
# memory usage: 24.6+ MB

# %%
# Let's see the shape of df_df_EdStatsFootNote Data 
print('DataFrame Shape :' , df_EdStatsFootNote.shape)
# list of Cloumns Names of df_df_EdStatsFootNote
print(list(df_EdStatsFootNote.columns.values))
# Out:
# DataFrame Shape : (643638, 5)
# ['CountryCode', 'SeriesCode', 'Year', 'DESCRIPTION', 'Unnamed: 4']

# %%
df_EdStatsFootNote.head()
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION  Unnamed: 4
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN
# 2         ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.         NaN
# 3         ABW  SE.SEC.ENRL.GC  YR2004  Country estimation.         NaN
# 4         ABW     SE.PRE.TCHR  YR2006  Country estimation.         NaN

# %%
df_EdStatsFootNote.tail()
# Out:
#        CountryCode   SeriesCode    Year  \
# 643633         ZWE  SH.DYN.MORT  YR2007
# 643634         ZWE  SH.DYN.MORT  YR2014
# 643635         ZWE  SH.DYN.MORT  YR2015
# 643636         ZWE  SH.DYN.MORT  YR2017
# 643637         ZWE  SP.POP.GROW  YR2017
#
#                                    DESCRIPTION  Unnamed: 4
# 643633       Uncertainty bound is 91.6 - 109.3         NaN
# 643634          Uncertainty bound is 54.3 - 76         NaN
# 643635        Uncertainty bound is 48.3 - 73.3         NaN
# 643636  5-year average value between 0s and 5s         NaN
# 643637  5-year average value between 0s and 5s         NaN

# %% [markdown]
# #### Let's see "EdStatsCountry-Series" data
# * It contains indicators and data sources for certain countries

# %%
df_EdStatsCountry_Series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613 entries, 0 to 612
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CountryCode  613 non-null    object
#  1   SeriesCode   613 non-null    object
#  2   DESCRIPTION  613 non-null    object
#  3   Unnamed: 3   0 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 19.3+ KB

# %%
# Let's see the shape of df_EdStatsCountry_Series Data 
print('DataFrame Shape :' , df_EdStatsCountry_Series.shape)
# list of Cloumns Names of df_EdStatsCountry_Series
print(list(df_EdStatsCountry_Series.columns.values))
# Out:
# DataFrame Shape : (613, 4)
# ['CountryCode', 'SeriesCode', 'DESCRIPTION', 'Unnamed: 3']

# %% [markdown]
# # After watch the all data, we have decided to work two database df_EdStatsCountry and df_EdStatsData most of the time

# %% [markdown]
# # CLEANING THE DATA:
#
# ### After this analysis of column names, we have decided to mainly focus on two important dataframes: con and data.
# df_EdStatsSeries is having the introduction of the countries code.
#
# df_EdStatsFootNote also have seriescode and country code.
#
# df_EdStatsCountry_Series file checking the periodicity and other commnets for each country.
#
# As far as our objective is concerned we need to work extensively on two dataframes: df_EdSatatsDataand df_StatsCountryData
#
# ##So Let's Start Playing With The Data, for proper lookup of the files!

# %%
a=df_EdStatsCountry.isnull().sum().sort_values(ascending=False)
plt.rcParams['figure.figsize']=(10,8)
a.plot(kind='bar')
plt.title('Showing the Null Values ')
# Out:
# Text(0.5, 1.0, 'Showing the Null Values ')

# %% [markdown]
# #####  **Observation:** Columns which are mostly empty are: 'Special Notes','National accounts reference year','Lending category','Other Groups','Alternative conversion Factor','PPP survey year','External Depth Reporting Status','Latest household survey','Vital redisteration complete','Latest industrial data'*

# %% [markdown]
# #### **Now try to analyse No. of Null values of columns in "EdStatsData" database with the help of visualization in bar chart**

# %%
a=df_EdStatsData.isnull().sum().sort_values(ascending=False)
plt.rcParams['figure.figsize']=(12,9)
a.plot(kind='bar')
plt.title('Showing the Null Values ')
# Out:
# Text(0.5, 1.0, 'Showing the Null Values ')

# %% [markdown]
# ##### **Observation:** most of the year columns are having null values.
# Since these columns are showing the trends, we can extrapolte them with the help of ffill() and bfill() methods*

# %% [markdown]
# It is observed that in all the files the Country Name column not only name is there but groups*(like 'Dominican Republic', 'East Asia & Pacific','East Asia & Pacific (all income levels)', 'Europe & Central Asia','Europe & Central Asia (all income levels)')* are also mentioned.
#
# To clean the data, a dictionary of currently existing country(Source:https://pytutorial.com/python-country-list ) is prepared and on that basis we will select the countries only and drop everything else.
#
# Now the dataframe we recievied will be having only country names in them.
# Then we will move ahead with the NULL cells.

# %%
country={"AF":"Afghanistan","AX":"Aland Islands","AL":"Albania","DZ":"Algeria","AS":"American Samoa","AD":"Andorra","AO":"Angola","AI":"Anguilla","AQ":"Antarctica","AG":"Antigua and Barbuda","AR":"Argentina",
         "AM":"Armenia","AW":"Aruba","AU":"Australia","AT":"Austria","AZ":"Azerbaijan","BS":"Bahamas","BH":"Bahrain","BD":"Bangladesh","BB":"Barbados","BY":"Belarus","BE":"Belgium","BZ":"Belize","BJ":"Benin",
         "BM":"Bermuda","BT":"Bhutan","BO":"Bolivia","BQ":"Bonaire, Sint Eustatius and Saba","BA":"Bosnia and Herzegovina","BW":"Botswana","BV":"Bouvet Island","BR":"Brazil",
         "IO":"British Indian Ocean Territory","BN":"Brunei Darussalam","BG":"Bulgaria","BF":"Burkina Faso","BI":"Burundi","KH":"Cambodia","CM":"Cameroon","CA":"Canada","CV":"Cape Verde","KY":"Cayman Islands",
         "CF":"Central African Republic","TD":"Chad","CL":"Chile","CN":"China","CX":"Christmas Island","CC":"Cocos Islands","CO":"Colombia","KM":"Comoros","CG":"Congo","CD":"Congo","CK":"Cook Islands",
         "CR":"Costa Rica","CI":"Côte d'Ivoire","HR":"Croatia","CU":"Cuba","CW":"Curaçao","CY":"Cyprus","CZ":"Czech Republic","DK":"Denmark","DJ":"Djibouti","DM":"Dominica","DO":"Dominican Republic",
         "EC":"Ecuador","EG":"Egypt","SV":"El Salvador","GQ":"Equatorial Guinea","ER":"Eritrea","EE":"Estonia","ET":"Ethiopia","FK":"Falkland Islands","FO":"Faroe Islands","FJ":"Fiji","FI":"Finland",
         "FR":"France","GF":"French Guiana","PF":"French Polynesia","TF":"French Southern Territories","GA":"Gabon","GM":"Gambia","GE":"Georgia","DE":"Germany","GH":"Ghana","GI":"Gibraltar","GR":"Greece",
         "GL":"Greenland","GD":"Grenada","GP":"Guadeloupe","GU":"Guam","GT":"Guatemala","GG":"Guernsey","GN":"Guinea","GW":"Guinea-Bissau","GY":"Guyana","HT":"Haiti","HM":"Heard Island and McDonald Islands",
         "VA":"Holy See","HN":"Honduras","HK":"Hong Kong","HU":"Hungary","IS":"Iceland","IN":"India","ID":"Indonesia","IR":"Iran, Islamic Republic of","IQ":"Iraq","IE":"Ireland",
         "IM":"Isle of Man","IL":"Israel","IT":"Italy","JM":"Jamaica","JP":"Japan","JE":"Jersey","JO":"Jordan","KZ":"Kazakhstan","KE":"Kenya","KI":"Kiribati","KP":"North Korea","KR":"South Korea",
         "KW":"Kuwait","KG":"Kyrgyzstan","LA":"Lao People's Democratic Republic","LV":"Latvia","LB":"Lebanon","LS":"Lesotho","LR":"Liberia","LY":"Libya","LI":"Liechtenstein","LT":"Lithuania",
         "LU":"Luxembourg","MO":"Macao","MK":"Macedonia","MG":"Madagascar","MW":"Malawi","MY":"Malaysia","MV":"Maldives","ML":"Mali","MT":"Malta","MH":"Marshall Islands","MQ":"Martinique",
         "MR":"Mauritania","MU":"Mauritius","YT":"Mayotte","MX":"Mexico","FM":"Micronesia","MD":"Moldova","MC":"Monaco","MN":"Mongolia","ME":"Montenegro","MS":"Montserrat",
         "MA":"Morocco","MZ":"Mozambique","MM":"Myanmar","NA":"Namibia","NR":"Nauru","NP":"Nepal","NL":"Netherlands","NC":"New Caledonia","NZ":"New Zealand","NI":"Nicaragua","NE":"Niger","NG":"Nigeria","NU":"Niue",
         "NF":"Norfolk Island","MP":"Northern Mariana Islands","NO":"Norway","OM":"Oman","PK":"Pakistan","PW":"Palau","PS":"Palestinian Territory, Occupied","PA":"Panama","PG":"Papua New Guinea","PY":"Paraguay",
         "PE":"Peru","PH":"Philippines","PN":"Pitcairn","PL":"Poland","PT":"Portugal","PR":"Puerto Rico","QA":"Qatar","RE":"Reunion","RO":"Romania","RU":"Russian Federation","RW":"Rwanda","BL":"Saint Barthélemy",
         "SH":"Saint Helena, Ascension and Tristan da Cunha","KN":"Saint Kitts and Nevis","LC":"Saint Lucia","MF":"Saint Martin (French part)","PM":"Saint Pierre and Miquelon","VC":"Saint Vincent and the Grenadines",
         "WS":"Samoa","SM":"San Marino","ST":"Sao Tome and Principe","SA":"Saudi Arabia","SN":"Senegal","RS":"Serbia","SC":"Seychelles","SL":"Sierra Leone","SG":"Singapore","SX":"Sint Maarten (Dutch part)","SK":"Slovakia",
         "SI":"Slovenia","SB":"Solomon Islands","SO":"Somalia","ZA":"South Africa","GS":"South Georgia and the South Sandwich Islands","ES":"Spain","LK":"Sri Lanka","SD":"Sudan","SR":"Suriname","SS":"South Sudan",
         "SJ":"Svalbard and Jan Mayen","SZ":"Swaziland","SE":"Sweden","CH":"Switzerland","SY":"Syrian Arab Republic","TW":"Taiwan","TZ":"Tanzania","TH":"Thailand","TL":"Timor-Leste",
         "TG":"Togo","TK":"Tokelau","TO":"Tonga","TT":"Trinidad and Tobago","TN":"Tunisia","TR":"Turkey","TM":"Turkmenistan","TC":"Turks and Caicos Islands","TV":"Tuvalu","UG":"Uganda","UA":"Ukraine","AE":"United Arab Emirates",
         "GB":"United Kingdom","US":"United States","UM":"United States Minor Outlying Islands","UY":"Uruguay","UZ":"Uzbekistan","VU":"Vanuatu","VE":"Venezuela","VN":"Viet Nam",
         "VG":"Virgin Islands, British","VI":"Virgin Islands, U.S.","WF":"Wallis and Futuna","YE":"Yemen","ZM":"Zambia","ZW":"Zimbabwe"
         }

# %%
country_list=list(country.values())

# %%
df_EdStatsCountry=df_EdStatsCountry[df_EdStatsCountry['Table Name'].isin(country_list)]

# %%
df_EdStatsData=df_EdStatsData[df_EdStatsData['Country Name'].isin(country_list)]

# %% [markdown]
# Also, to avoid the contamination of df_EdSatatsData we are making the copy of df_EdSatatsData file with the name: 'data_copy'

# %%
data_copy=df_EdStatsData.copy()

# %% [markdown]
# ### **To study the education trends** we will take data from last two decades
#
# Now shortlisting the columns from the year 2000 to 2030(to make the study simpler we are taking last two decades data), since there is very less(mostly Null) data present before 2001 and after 2015. But to analysis for near future can give us some insight, so we are selecting data till 2030.

# %%
#Lets now fill the data with the help of ffill() and bfill()
colm=['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
       '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
       '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
       '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
       '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
       '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
       '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
       '2095', '2100']
data_copy.loc[:,colm]=data_copy.loc[:,colm].bfill(axis='columns')
data_copy.loc[:,colm]=data_copy.loc[:,colm].ffill(axis='columns')

# %% [markdown]
# # **SECTION - "A" :**  *In this section we simply Just try to set our  hand in data with some interesting point as like try to found No. of country in Region and Various Income Group. we will try to see Population growth % of various countries catogriesed by Income Group. and also try to do visualize this together with help of various chart*

# %% [markdown]
# ## Now it's time to data clean , analyse and visaulize **together**

# %% [markdown]
# ## TASK1: Find the Numbers of countries according to  'Region'

# %%
df_country['Region'].value_counts()
# Out:
# Europe & Central Asia         57
# Sub-Saharan Africa            48
# Latin America & Caribbean     41
# East Asia & Pacific           36
# Middle East & North Africa    21
# South Asia                     8
# North America                  3
# Name: Region, dtype: int64

# %%
region_name = list(df_country['Region'].value_counts().keys())
region_name
# Out:
# ['Europe & Central Asia',
#  'Sub-Saharan Africa',
#  'Latin America & Caribbean',
#  'East Asia & Pacific',
#  'Middle East & North Africa',
#  'South Asia',
#  'North America']

# %%
no_coutry = list(df_country['Region'].value_counts())
no_coutry
# Out:
# [57, 48, 41, 36, 21, 8, 3]

# %%
plt.figure(figsize=(10,5))
plt.barh(region_name,no_coutry, color =["blue","green","red","pink","orange","grey","brown"])
plt.xlabel("Numbers of Coutry")
plt.ylabel("Names of Region")
plt.title("Graph representing No of countries per Region")
for index, value in enumerate(no_coutry):
    plt.text(value, index,
             str(value))
plt.show()

# %% [markdown]
# * Here we can easily found that how many coutries belongs from which region.

# %% [markdown]
# ## Task2: No of countries in each section of 'Income Group'

# %%
df_country['Income Group'].value_counts()
# Out:
# Upper middle income     55
# Lower middle income     50
# High income: nonOECD    44
# Low income              34
# High income: OECD       31
# Name: Income Group, dtype: int64

# %%
Income_Group = list(df_country['Income Group'].value_counts().keys())
Income_Group
# Out:
# ['Upper middle income',
#  'Lower middle income',
#  'High income: nonOECD',
#  'Low income',
#  'High income: OECD']

# %%
Income_Group_coutry = list(df_country['Income Group'].value_counts())
Income_Group_coutry
# Out:
# [55, 50, 44, 34, 31]

# %%
plt.figure(figsize = (10, 5) )
plt.barh(Income_Group,Income_Group_coutry, color = ["blue","red","pink","orange","silver"])
plt.xlabel("Numbers of Coutry")
plt.ylabel("Names of Income Group")
plt.title("Graph representing No of countries per Income Group")
for index, value in enumerate(Income_Group_coutry):
    plt.text(value, index,
             str(value))
plt.show()

# %% [markdown]
# * Here we can easily found that how many coutries belongs from which 'Income Group'.

# %% [markdown]
# ## TASK3: Analyse the Population growth % of various countries catogriesed by Income Group

# %%
df_StatsData = df_data.loc[:,['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code','2005','2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014']]

# %%
df_StatsData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   2005            184108 non-null  float64
#  5   2006            140312 non-null  float64
#  6   2007            137272 non-null  float64
#  7   2008            134387 non-null  float64
#  8   2009            142108 non-null  float64
#  9   2010            242442 non-null  float64
#  10  2011            146012 non-null  float64
#  11  2012            147264 non-null  float64
#  12  2013            137509 non-null  float64
#  13  2014            113789 non-null  float64
# dtypes: float64(10), object(4)
# memory usage: 94.7+ MB

# %%
merged_statseries_statdata =pd.merge(df_EdStatsSeries,df_StatsData, on='Indicator Name',how='inner')
merged_statseries_statdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 775126 entries, 0 to 775125
# Data columns (total 34 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Series Code                          775126 non-null  object
#  1   Topic                                775126 non-null  object
#  2   Indicator Name                       775126 non-null  object
#  3   Short definition                     502876 non-null  object
#  4   Long definition                      775126 non-null  object
#  5   Unit of measure                      0 non-null       float64
#  6   Periodicity                          4840 non-null    object
#  7   Base Period                          968 non-null     object
#  8   Other notes                          120274 non-null  object
#  9   Aggregation method                   4840 non-null    object
#  10  Limitations and exceptions           726 non-null     object
# ...

# %%
#merging the previously merged dataframe and df_StatsCountry with respect to Country code
merged_series_Data_country=pd.merge(merged_statseries_statdata,df_EdStatsCountry, on ='Country Code', how= 'inner')
merged_series_Data_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 595758 entries, 0 to 595757
# Data columns (total 65 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   Series Code                                        595758 non-null  object
#  1   Topic                                              595758 non-null  object
#  2   Indicator Name                                     595758 non-null  object
#  3   Short definition                                   386508 non-null  object
#  4   Long definition                                    595758 non-null  object
#  5   Unit of measure                                    0 non-null       float64
#  6   Periodicity                                        3720 non-null    object
#  7   Base Period                                        744 non-null     object
# ...

# %% [markdown]
# ####Separating the dataframe based on particular each Income groups

# %% [markdown]
# ##### Lower Income Group

# %%
#Data frame for lower income group
df_lowerincome=merged_series_Data_country.loc[merged_series_Data_country['Income Group']=='Low income',:]

# %%
#unique country names
df_lowerincome['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Bangladesh', 'Benin', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Central African Republic', 'Chad', 'Comoros',
#        'Eritrea', 'Ethiopia', 'Guinea', 'Guinea-Bissau', 'Haiti', 'Kenya',
#        'Liberia', 'Madagascar', 'Malawi', 'Mali', 'Mozambique', 'Myanmar',
#        'Nepal', 'Niger', 'Rwanda', 'Sierra Leone', 'Somalia', 'Tanzania',
#        'Togo', 'Uganda', 'Zimbabwe'], dtype=object)

# %%
#created a list of some country names which we are already familiar to make our analysis easy
countrylist1=['Afghanistan', 'Bangladesh','Nepal','Zimbabwe','Myanmar']

# %%
df_lowerincome=df_lowerincome.loc[df_lowerincome['Country Name'].isin(countrylist1),:]

# %%
lowerincome_df_Population=df_lowerincome.loc[df_lowerincome['Topic']=='Health: Population: Dynamics',:]

# %%
lowerincome_df_Population.columns
# Out:
# Index(['Series Code', 'Topic', 'Indicator Name', 'Short definition',
#        'Long definition', 'Unit of measure', 'Periodicity', 'Base Period',
#        'Other notes', 'Aggregation method', 'Limitations and exceptions',
#        'Notes from original source', 'General comments', 'Source',
#        'Statistical concept and methodology', 'Development relevance',
#        'Related source links', 'Other web links', 'Related indicators',
#        'License Type', 'Unnamed: 20', 'Country Name', 'Country Code',
#        'Indicator Code', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', 'Short Name', 'Table Name', 'Long Name',
#        '2-alpha code', 'Currency Unit', 'Special Notes', 'Region',
#        'Income Group', 'WB-2 code', 'National accounts base year',
#        'National accounts reference year', 'SNA price valuation',
#        'Lending category', 'Other groups', 'System of National Accounts',
# ...

# %%
lowerincome_df_Population=lowerincome_df_Population[['Country Name', '2005', '2006','2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014']]
lowerincome_df_Population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 2127 to 594682
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  5 non-null      object
#  1   2005          5 non-null      float64
#  2   2006          5 non-null      float64
#  3   2007          5 non-null      float64
#  4   2008          5 non-null      float64
#  5   2009          5 non-null      float64
#  6   2010          5 non-null      float64
#  7   2011          5 non-null      float64
#  8   2012          5 non-null      float64
#  9   2013          5 non-null      float64
#  10  2014          5 non-null      float64
# dtypes: float64(10), object(1)
# memory usage: 480.0+ bytes

# %%
#setting the country name as index
lowerincome_df_Population.set_index(lowerincome_df_Population['Country Name'], inplace=True)
#since country name is already our index so dropping the country name column
lowerincome_df_Population.drop('Country Name',axis=1,inplace=True)
lowerincome_df_Population.head()
# Out:
#                   2005      2006      2007      2008      2009      2010  \
# Country Name
# Afghanistan   3.870470  3.228630  2.755225  2.512574  2.569114  2.812617
# Bangladesh    1.491650  1.341370  1.211053  1.126318  1.101990  1.119888
# Myanmar       0.846986  0.747694  0.663374  0.624760  0.646530  0.710724
# Nepal         1.298702  1.164518  1.051593  0.990741  0.996848  1.049161
# Zimbabwe      1.263909  1.413720  1.554735  1.700106  1.842497  1.976756
#
#                   2011      2012      2013      2014
# Country Name
# Afghanistan   3.095119  3.272703  3.315224  3.183201
# Bangladesh    1.151949  1.172435  1.177319  1.157188
# Myanmar       0.788683  0.853826  0.901423  0.920922
# Nepal         1.118718  1.174241  1.205671  1.200297
# Zimbabwe      2.109672  2.228306  2.309366  2.344799

# %%
#using front fill to fill our NaN values in row
lowerincome_df_Population=lowerincome_df_Population.ffill(axis=1)

#taking transpose to make our plot easy, the x axis will contain the years 
lowerincome_df_Population=lowerincome_df_Population.transpose()
lowerincome_df_Population
# Out:
# Country Name  Afghanistan  Bangladesh   Myanmar     Nepal  Zimbabwe
# 2005             3.870470    1.491650  0.846986  1.298702  1.263909
# 2006             3.228630    1.341370  0.747694  1.164518  1.413720
# 2007             2.755225    1.211053  0.663374  1.051593  1.554735
# 2008             2.512574    1.126318  0.624760  0.990741  1.700106
# 2009             2.569114    1.101990  0.646530  0.996848  1.842497
# 2010             2.812617    1.119888  0.710724  1.049161  1.976756
# 2011             3.095119    1.151949  0.788683  1.118718  2.109672
# 2012             3.272703    1.172435  0.853826  1.174241  2.228306
# 2013             3.315224    1.177319  0.901423  1.205671  2.309366
# 2014             3.183201    1.157188  0.920922  1.200297  2.344799

# %% [markdown]
# ##### Lower Middle Income Group

# %%
#creating a function that will take a dataframe and list of countries and will return a dataframe with required columns and rows
def newdf(anydf,countrylst):
  anydf=anydf.loc[anydf['Country Name'].isin(countrylst),:]
  anydf_df_Population=anydf.loc[anydf['Topic']=='Health: Population: Dynamics',:]
  anydf_df_Population=anydf_df_Population[['Country Name', '2005', '2006','2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014']]
  anydf_df_Population.set_index(anydf_df_Population['Country Name'], inplace=True,)
  anydf_df_Population.drop('Country Name',axis=1,inplace=True)
  anydf_df_Population=anydf_df_Population.ffill(axis=1)
  anydf_df_Population=anydf_df_Population.transpose()
  return anydf_df_Population

# %%
#dataframe for Lower middle Income group
df_lowermiddle = merged_series_Data_country.loc[merged_series_Data_country['Income Group']=='Lower middle income']

# %%
#analysing the lower middle income group
df_lowermiddle['Country Name'].unique()
# Out:
# array(['Armenia', 'Bhutan', 'Bolivia', 'Cameroon', "Cote d'Ivoire",
#        'Djibouti', 'El Salvador', 'Georgia', 'Ghana', 'Guatemala',
#        'Guyana', 'Honduras', 'India', 'Indonesia', 'Kiribati', 'Lesotho',
#        'Mauritania', 'Moldova', 'Mongolia', 'Morocco', 'Nicaragua',
#        'Nigeria', 'Pakistan', 'Papua New Guinea', 'Paraguay',
#        'Philippines', 'Samoa', 'Senegal', 'Solomon Islands',
#        'South Sudan', 'Sri Lanka', 'Sudan', 'Swaziland',
#        'Syrian Arab Republic', 'Timor-Leste', 'Ukraine', 'Uzbekistan',
#        'Vanuatu', 'Zambia'], dtype=object)

# %%
#created a list of some country names which we are already familiar to make our analysis easy
countrylist2=['India','Sri Lanka','Pakistan','Bhutan','Indonesia']

#calling function newdf to return a new dataframe with selected rows and columns
lowermidDf = newdf(df_lowermiddle,countrylist2)
lowermidDf
# Out:
# Country Name    Bhutan     India  Indonesia  Pakistan  Sri Lanka
# 2005          2.522570  1.584252   1.375946  2.054204   0.751279
# 2006          2.346317  1.548886   1.369188  2.047846   0.755924
# 2007          2.167559  1.512078   1.361626  2.040843   0.755337
# 2008          2.016340  1.469688   1.351463  2.044428   0.754721
# 2009          1.908766  1.420203   1.338066  2.059363   0.759084
# 2010          1.828358  1.366798   1.321405  2.079755   0.753365
# 2011          1.753134  1.311876   1.304067  2.102553   0.752665
# 2012          1.668226  1.261206   1.284199  2.117269   0.756835
# 2013          1.580345  1.219419   1.257327  2.113987   0.780301
# 2014          1.490482  1.189328   1.222049  2.087792   0.899513

# %% [markdown]
# ##### Uper Middle Income Group

# %%
#dataframe for upper middle income group
df_uppermiddle=merged_series_Data_country.loc[merged_series_Data_country['Income Group']=='Upper middle income']

# %%
df_uppermiddle['Country Name'].unique()
# Out:
# array(['Albania', 'Algeria', 'American Samoa', 'Angola', 'Argentina',
#        'Azerbaijan', 'Belarus', 'Belize', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Bulgaria', 'China', 'Colombia',
#        'Costa Rica', 'Cuba', 'Dominica', 'Dominican Republic', 'Ecuador',
#        'Fiji', 'Gabon', 'Grenada', 'Hungary', 'Iraq', 'Jamaica', 'Jordan',
#        'Kazakhstan', 'Lebanon', 'Libya', 'Malaysia', 'Maldives',
#        'Marshall Islands', 'Mauritius', 'Mexico', 'Montenegro', 'Namibia',
#        'Palau', 'Panama', 'Peru', 'Romania', 'Serbia', 'Seychelles',
#        'South Africa', 'Suriname', 'Thailand', 'Tonga', 'Tunisia',
#        'Turkey', 'Turkmenistan', 'Tuvalu'], dtype=object)

# %%
#created a list of some country names which we are already familiar to make our analysis easy
countrylist3=['China','Brazil','South Africa','Thailand','Malaysia']

upper_middle_df = newdf(df_uppermiddle,countrylist3)
upper_middle_df
# Out:
# Country Name    Brazil     China  Malaysia  South Africa  Thailand
# 2005          1.172552  0.588125  1.909366      1.278909  0.649004
# 2006          1.114609  0.558374  1.869341      1.308723  0.607537
# 2007          1.060019  0.522272  1.827924      1.338686  0.562722
# 2008          1.016865  0.512387  1.805973      1.368812  0.527561
# 2009          0.988454  0.497381  1.806870      1.399113  0.503805
# 2010          0.970296  0.482960  1.819602      1.429604  0.487643
# 2011          0.956013  0.479150  1.842740      1.460296  0.476956
# 2012          0.938920  0.487231  1.852220      1.491203  0.463677
# 2013          0.917023  0.493710  1.821700      1.522336  0.439875
# 2014          0.887563  0.506312  1.739579      1.553706  0.400861

# %% [markdown]
# ##### Non-OECD High Income Group

# %%
#dataframe for higher Non-OECD Income group
df_highincome_nonoecd=merged_series_Data_country.loc[merged_series_Data_country['Income Group']=='High income: nonOECD',:]

# %%
df_highincome_nonoecd['Country Name'].unique()
# Out:
# array(['Andorra', 'Antigua and Barbuda', 'Aruba', 'Bahrain', 'Barbados',
#        'Bermuda', 'Brunei Darussalam', 'Cayman Islands', 'Croatia',
#        'Curacao', 'Cyprus', 'Equatorial Guinea', 'French Polynesia',
#        'Greenland', 'Guam', 'Isle of Man', 'Kuwait', 'Latvia',
#        'Liechtenstein', 'Lithuania', 'Malta', 'Monaco', 'New Caledonia',
#        'Northern Mariana Islands', 'Oman', 'Puerto Rico', 'Qatar',
#        'Russian Federation', 'San Marino', 'Saudi Arabia', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Trinidad and Tobago',
#        'Turks and Caicos Islands', 'United Arab Emirates', 'Uruguay'],
#       dtype=object)

# %%
#created a list of some country names which we are already familiar to make our analysis easy
countrylist4 = ['Saudi Arabia', 'Singapore','United Arab Emirates','Kuwait','Oman']

NonoecdDf=newdf(df_highincome_nonoecd,countrylist4)
NonoecdDf
# Out:
# Country Name    Kuwait      Oman  Saudi Arabia  Singapore  \
# 2005          3.063370  2.684493      2.871824   2.350511
# 2006          4.325452  2.815983      2.774898   3.129389
# 2007          5.170608  3.041590      2.706391   4.166003
# 2008          5.778847  3.550944      2.688797   5.321517
# 2009          6.091830  4.393793      2.740441   3.015950
# 2010          6.161251  5.352636      2.825938   1.771833
# 2011          6.237725  6.239210      2.918964   2.084902
# 2012          6.211719  6.788012      2.959994   2.453390
# 2013          5.801762  6.882110      2.907563   1.619308
# 2014          4.988681  6.504660      2.741376   1.298440
#
# Country Name  United Arab Emirates
# 2005                     11.356439
# 2006                     13.510585
# 2007                     14.236792
# 2008                     13.161466
# 2009                     10.615444
# 2010                      7.587098
# 2011                      4.743700
# 2012                      2.594796
# ...

# %% [markdown]
# #####OECD High income group

# %%
#dataframe for higher income group OECD (OECD means Organisation for Economic Co-operation and Development)
df_highincome_Oecd=merged_series_Data_country.loc[merged_series_Data_country['Income Group']=='High income: OECD',:]

# %%
df_highincome_Oecd['Country Name'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Chile',
#        'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Iceland', 'Ireland', 'Israel', 'Italy',
#        'Japan', 'Luxembourg', 'Netherlands', 'New Zealand', 'Norway',
#        'Poland', 'Portugal', 'Slovenia', 'Spain', 'Sweden', 'Switzerland',
#        'United Kingdom', 'United States'], dtype=object)

# %%
countrylist5 = ['Australia','Canada','Japan','United Kingdom','United States']

#calling the fuction that will return the required rows and columns
oecdDf=newdf(df_highincome_Oecd,countrylist5)
oecdDf
# Out:
# Country Name  Australia    Canada     Japan  United Kingdom  United States
# 2005           1.319790  0.985904  0.009392        0.686611       0.921713
# 2006           1.475228  0.796845  0.063374        0.735049       0.964254
# 2007           0.624678  0.969854  0.114909        0.778666       0.951055
# 2008           2.004022  1.082197  0.048425        0.787033       0.945865
# 2009           2.061045  1.144840 -0.012495        0.756391       0.876651
# 2010           1.555490  1.113960  0.017961        0.783889       0.836422
# 2011           1.389527  0.987618 -0.185226        0.781677       0.745614
# 2012           1.722895  1.180345 -0.159711        0.695316       0.746420
# 2013           1.697473  1.158443 -0.144272        0.669534       0.700262
# 2014           1.474288  1.100755 -0.132694        0.753349       0.743124

# %% [markdown]
# ##### Now we are adding to analyse for the five countries from all the five different income groups

# %%
#this list has country names from all the five different income groups
list6=['India','China','United States','Oman','Nepal']

# %%
#now we are going to analyse for the five countries
CombinePopulationDf=newdf(merged_series_Data_country,list6)

# %% [markdown]
# #### Now try to visualize it  by line chart

# %%
#Please  Run this cell again
# Some example data to display
fig, axs = plt.subplots(3,2)
plt.rcParams["figure.figsize"] = (20,25)



axs[0,0].plot(lowerincome_df_Population)
axs[0,0].legend(list(lowerincome_df_Population.columns),
        loc='upper right', title='Countries')
axs[0,0].set_xlabel("Years")
axs[0,0].set_title("Countries of Lower Income Group")
axs[0,0].set_ylabel("Population growth %")


axs[0,1].plot(lowermidDf)
axs[0,1].legend(list(lowermidDf.columns),
        loc='upper right', title='Countries')
axs[0,1].set_xlabel("Years")
axs[0,1].set_title("Countries of Lower Middle Income Group")
axs[0,1].set_ylabel("Population growth %")

axs[1,0].plot(upper_middle_df)
axs[1,0].legend(list(upper_middle_df.columns),
        loc='upper right', title='Countries')
axs[1,0].set_xlabel("Years")
axs[1,0].set_title('Countries of Uper Middle Income Group')
axs[1,0].set_ylabel("Population growth %")

axs[1,1].plot(NonoecdDf)
axs[1,1].legend(list(NonoecdDf.columns),
        loc='upper right', title='Countries')
axs[1,1].set_xlabel("Years")
axs[1,1].set_title('Countries of Non-OECD High Income Group')
axs[1,1].set_ylabel("Population growth %")

axs[2,0].plot(oecdDf)
axs[2,0].legend(list(oecdDf.columns),
        loc='upper right', title='Countries')
axs[2,0].set_xlabel("Years")
axs[2,0].set_title('Countries of OECD High Income Group')
axs[2,0].set_ylabel("Population growth %")

axs[2,1].plot(CombinePopulationDf)
axs[2,1].legend(list(CombinePopulationDf.columns),
        loc='upper right', title='Countries')
axs[2,1].set_xlabel("Years")
axs[2,1].set_title('Countries From all the five different Income Groups')
axs[2,1].set_ylabel("Population growth %")
# Out:
# Text(0, 0.5, 'Population growth %')

# %% [markdown]
# # **SECTION - "B"** : *Now, We are quite familiar to all data. So, In this section we are going to analyse some more interesting point just like To study the education trends, to visualize percentage ratio of "Developed Countries" and "Developing coutries", GDP (Gross domestic product) of 3 top and bottom countries of "Developed Countries" and "Developing coutries" , try to Deep analysis of education scenario in India and also try to Observe the capital expenditure at various levels*

# %% [markdown]
# # **PART-I**

# %% [markdown]
# ## TASK1: Show on the pie chart the number of developed and developing countries

# %% [markdown]
# Crowded graphs are not easy to analyse and we might miss basic observations in them, to avoid that we are selecting only the even years from the last 2 decades i.e. ['2000','2002','2004','2006','2008','2010','2012','2014','2016','2020','2025','2030']

# %%
# selecting last two decades data and 2025 and 2030 for future refernce
data_copy=data_copy[['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code','2000', '2002', '2004', '2006', '2008', '2010', '2012', '2014', '2016', '2020', '2025', '2030']].copy()

# %% [markdown]
# The most current World Bank Income classifications by GNI per capita (updated July 1 of every year) are as follows[7]:
#
# Low income: $1,025 or less
#
# Lower middle income:  1,026to 4,035
#
# Upper middle income:  4,036to 12,475
#
# High income: $12,476 or more
#
# Low- and middle-income economies are usually referred to as developing economies, and the Upper Middle Income and the High Income are referred to as Developed Countries.
# (Source: https://www.a4id.org/policy/understanding-the-developeddeveloping-country-taxonomy/)

# %% [markdown]
# ## Its the time to make the list for 'Developing Countries and Developed Countries'.

# %%
developing=[]
developed=[]
for index,row in df_EdStatsCountry.iterrows():
  if row['Income Group'] in ['Low income','Lower middle income']:
    developing.append(row['Table Name'])
  elif row['Income Group'] in ['High income: nonOECD','Upper middle income','High income: OECD']:
    developed.append(row['Table Name'])
  else:
    pass

# %%
#printing the list of developed and developing nations
print('Developed Nations:', developed)
print("Developing Nations:", developing)
# Out:
# Developed Nations: ['Aruba', 'Angola', 'Albania', 'Andorra', 'United Arab Emirates', 'Argentina', 'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan', 'Belgium', 'Bulgaria', 'Bahrain', 'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Botswana', 'Canada', 'Switzerland', 'Chile', 'China', 'Colombia', 'Costa Rica', 'Cuba', 'Curaçao', 'Cayman Islands', 'Cyprus', 'Czech Republic', 'Germany', 'Dominica', 'Denmark', 'Dominican Republic', 'Algeria', 'Ecuador', 'Spain', 'Estonia', 'Finland', 'Fiji', 'France', 'Gabon', 'United Kingdom', 'Equatorial Guinea', 'Greece', 'Grenada', 'Greenland', 'Guam', 'Croatia', 'Hungary', 'Isle of Man', 'Ireland', 'Iraq', 'Iceland', 'Israel', 'Italy', 'Jamaica', 'Jordan', 'Japan', 'Kazakhstan', 'Kuwait', 'Lebanon', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Latvia', 'Monaco', 'Maldives', 'Mexico', 'Marshall Islands', 'Malta', 'Montenegro', 'Northern Mariana Islands', 'Mauri
# ...

# %%
y = list([len(developed),len(developing)])
mylabels = ["Developed Coutries","Developing countries"]

plt.figure(figsize=(5,5))
plt.pie(y, labels = mylabels, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.legend()
plt.title("percentage ratio of 'Developed Countries' and 'Developing coutries'")
plt.show()

# %% [markdown]
# ### Lets see if India lies in developed or developing nations

# %%
#Just I'm a little curious to check where my country lies between developed and developing nations
a='India'
if a in developed:
  print(f'{a} is a developed nation')
if a in developing:
  print(f'{a} is a developing nation')
# Out:
# India is a developing nation

# %% [markdown]
# ## TASK2: GDP (Gross domestic product) of 3 top and bottom countries in the year 2020, do this task for deveoped and developing nations separately
#
# Pay Attention: Here data from dataframe named 'df_StatsCountryData' has been compared with the another dataframe named 'data'

# %%
#making the copy for this task
data_gdp=data_copy[['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code','2020']].copy()

# %%
#Function that will make 2 data frames one having information of developed countries and another for developing countries
def separating_nations (all_nations,ed_nations,ing_nations):
  df_ed=all_nations.copy()
  df_ing=all_nations.copy()
  for index,row in all_nations.iterrows():
    if row['Country Name'] not in ed_nations:
      df_ed.drop(index,inplace=True)
    elif row['Country Name'] not in ing_nations:
      df_ing.drop(index,inplace=True)
    else:
      df_ed.drop(index,inplace=True)
      df_ing.drop(index,inplace=True)
  return df_ed,df_ing

# %%
# selecting the GDP data rows only and eliminating the null
data_gdp=data_gdp[data_gdp['Indicator Code']=='NY.GDP.PCAP.PP.CD']
data_gdp=data_gdp[~data_gdp['2020'].isna()]
df1,df2=separating_nations(data_gdp,developing,developed)
# df1 and df2 are for developing and developed nations respectively

# %%
#sorting the GDP 2020 year values in decending order
df1=df1.sort_values('2020',ascending=False)
df2=df2.sort_values('2020',ascending=False)

# %%
# Defining a function to get the top 3 and bottom 3 countries on the basis of GDP in the year 2020
def get_top_bottom_nation (df):
  a=df.head(3)
  b=df.tail(3)
  a=a.append(b,ignore_index=True)
  return a

# %%
developed_con_top_bottom = get_top_bottom_nation(df2)

# %%
# getting top and bottom 3 countries for the developed nation
plt.rcParams['figure.figsize']=(10,6)
developed_con_top_bottom.plot(x='Country Name',y='2020',kind='bar',color=['g','g','g','b','b','b'])
plt.grid(True)
plt.title('Top and Bottom three GDP values comparision for 2020 for Developed nations',fontsize=20,color='r')
plt.ylabel('GDP value in 2020')
# Out:
# Text(0, 0.5, 'GDP value in 2020')

# %%
developing_con_top_bottom = get_top_bottom_nation(df1)
developing_con_top_bottom=developing_con_top_bottom.append(df1[df1['Country Name']=='India'])

# %%
# getting top and bottom 3 countries for the developing nations
plt.rcParams['figure.figsize']=(10,6)
developing_con_top_bottom.plot(x='Country Name',y='2020',kind='bar',color=['g','g','g','b','b','b','r'])
plt.grid(True)
plt.title('Top and Bottom three GDP values comparision for 2020 for developing countries, including India',fontsize=20,color='r')
plt.ylabel('GDP value in 2020')
# Out:
# Text(0, 0.5, 'GDP value in 2020')

# %% [markdown]
# ## PART-II: Deep analysis of education scenario in India

# %% [markdown]
# ### We are going limiting our study to one country only: 'India' for the last decade
# The same model can be applied to other counties also.
#
# Here we are doing primary, lower-secodary, upper-secondary and tertiary analysis on Indian population. Also, we are bifurcating these on gender.

# %%
#Lets make a copy which will have only 'India' under Country Name column
data_india=data_copy[data_copy['Country Name']=='India']

# %% [markdown]
# ### TASK1: Analysis of Adjusted net enrolment rate calculated
#
# Adjusted net enrolment rate calculated by dividing the number of children in the official primary school age who are enrolled in primary or secondary education by the population of the same age group and multiplying by 100.

# %%
AER_india=data_india.copy()

# %%
AER_code_list=['UIS.NERA.2','UIS.NERA.2.F','UIS.NERA.2.M','SE.PRM.TENR','SE.PRM.TENR.FE','SE.PRM.TENR.MA','UIS.NERA.3','UIS.NERA.3.F','UIS.NERA.3.M']

# %%
for index,row in AER_india.iterrows():
  if row['Indicator Code'] in (AER_code_list):
    pass
  else:
    AER_india.drop(index,inplace=True)

# %%
plt.rcParams['figure.figsize']=(15,8)
#just choose certain years for proper anlysis
AER_india.plot(y=['2000', '2002', '2004', '2006', '2008', '2010', '2012', '2014', '2016', '2020', '2025', '2030'],x='Indicator Name',kind='bar')
plt.xticks(rotation=90)
plt.grid(True)
plt.title("Analysis of education scenario in India")
# Out:
# Text(0.5, 1.0, 'Analysis of education scenario in India')

# %% [markdown]
# ### Now, lets focus on the education of young generation (age: 20 to 40) for even years from the past two decades

# %% [markdown]
# ## TASK2: Barro-Lee: 20-24 age group education analysis

# %%
edu2024_india=data_india.copy()

# %%
edu2024_code_list=['BAR.NOED.2024.FE.ZS','BAR.PRM.CMPT.2024.FE.ZS','BAR.SEC.CMPT.2024.FE.ZS','BAR.TER.CMPT.2024.FE.ZS','BAR.NOED.2024.ZS','BAR.PRM.CMPT.2024.ZS','BAR.SEC.CMPT.2024.ZS','BAR.TER.CMPT.2024.ZS']

# %%
for index,row in edu2024_india.iterrows():
  if row['Indicator Code'] in (edu2024_code_list):
    pass
  else:
    edu2024_india.drop(index,inplace=True)

# %%
plt.rcParams['figure.figsize']=(15,8)
edu2024_india.plot(y=['2000', '2002', '2004', '2006', '2008', '2010', '2012', '2014', '2016', '2020', '2025', '2030'],x='Indicator Name',kind='bar')
plt.xticks(rotation=90)
plt.grid(True)
plt.title("Barro-Lee: 20-24 age group education analysis")
# Out:
# Text(0.5, 1.0, 'Barro-Lee: 20-24 age group education analysis')

# %% [markdown]
# ## TASK3: Barro-Lee: 25-29 age group education analysis

# %%
edu2529_india=data_india.copy()

# %%
edu2529_code_list=['BAR.NOED.2529.FE.ZS','BAR.NOED.2529.ZS','BAR.PRM.CMPT.2529.FE.ZS', 'BAR.PRM.CMPT.2529.ZS','BAR.SEC.CMPT.2529.FE.ZS','BAR.SEC.CMPT.2529.ZS','BAR.TER.CMPT.2529.FE.ZS','BAR.TER.CMPT.2529.ZS']

# %%
for index,row in edu2529_india.iterrows():
  if row['Indicator Code'] in (edu2529_code_list):
    pass
  else:
    edu2529_india.drop(index,inplace=True)

# %%
plt.rcParams['figure.figsize']=(15,8)
edu2529_india.plot(y=['2000', '2002', '2004', '2006', '2008', '2010', '2012', '2014', '2016', '2020', '2025', '2030'],x='Indicator Name',kind='bar')
plt.xticks(rotation=90)
plt.grid()
plt.title("Barro-Lee: 25-29 age group education analysis")
# Out:
# Text(0.5, 1.0, 'Barro-Lee: 25-29 age group education analysis')

# %% [markdown]
# ## TASK4: Barro-Lee: 30-34 age group education analysis

# %%
edu3034_india=data_india.copy()

# %%
edu3034_code_list=['BAR.NOED.3034.FE.ZS','BAR.PRM.CMPT.3034.FE.ZS','BAR.SEC.CMPT.3034.FE.ZS','BAR.TER.CMPT.3034.FE.ZS','BAR.NOED.3034.ZS','BAR.PRM.CMPT.3034.ZS','BAR.SEC.CMPT.3034.ZS','BAR.TER.CMPT.3034.ZS']

# %%
for index,row in edu3034_india.iterrows():
  if row['Indicator Code'] in (edu3034_code_list):
    pass
  else:
    edu3034_india.drop(index,inplace=True)

# %%
plt.rcParams['figure.figsize']=(15,8)
edu3034_india.plot(y=['2000', '2002', '2004', '2006', '2008', '2010', '2012', '2014', '2016', '2020', '2025', '2030'],x='Indicator Name',kind='bar')
plt.xticks(rotation=90)
plt.grid(True)
plt.title("Barro-Lee: 30-34 age group education analysis")
# Out:
# Text(0.5, 1.0, 'Barro-Lee: 30-34 age group education analysis')

# %% [markdown]
# ## TASK5: Barro-Lee: 35-39 age group education analysis

# %%
edu3539_india=data_india.copy()

# %%
edu3539_code_list=['BAR.NOED.3539.FE.ZS','BAR.PRM.CMPT.3539.FE.ZS','BAR.SEC.CMPT.3539.FE.ZS','BAR.TER.CMPT.3539.FE.ZS','BAR.NOED.3539.ZS','BAR.PRM.CMPT.3539.ZS','BAR.SEC.CMPT.3539.ZS','BAR.TER.CMPT.3539.ZS']

# %%
for index,row in edu3539_india.iterrows():
  if row['Indicator Code'] in (edu3539_code_list):
    pass
  else:
    edu3539_india.drop(index,inplace=True)

# %%
plt.rcParams['figure.figsize']=(15,8)
edu3539_india.plot(y=['2000', '2002', '2004', '2006', '2008', '2010', '2012', '2014', '2016', '2020', '2025', '2030'],x='Indicator Name',kind='bar')
plt.xticks(rotation=90)
plt.grid(True)
plt.title("Barro-Lee: 35-39 age group education analysis")
# Out:
# Text(0.5, 1.0, 'Barro-Lee: 35-39 age group education analysis')

# %% [markdown]
# ## TASK6: Observe the capital expenditure at various levels

# %%
exp_edu_india=data_india.copy()

# %%
expenditure_list=['UIS.XSPENDP.2.FDPUB.FNCAP','UIS.XSPENDP.1.FDPUB.FNCAP','UIS.XSPENDP.FDPUB.FNCAP','UIS.XSPENDP.23.FDPUB.FNCAP','UIS.XSPENDP.56.FDPUB.FNCAP','UIS.XSPENDP.3.FDPUB.FNCAP']

# %%
for index,row in exp_edu_india.iterrows():
  if row['Indicator Code'] in (expenditure_list):
    pass
  else:
    exp_edu_india.drop(index,inplace=True)

# %%
exp_edu_india.plot(y=['2000', '2002', '2004', '2006', '2008', '2010', '2012', '2014', '2016', '2020', '2025', '2030'],x='Indicator Name')
plt.xticks(rotation=90)
plt.grid(True)
plt.title('The capital expenditure at various levels')
# Out:
# Text(0.5, 1.0, 'The capital expenditure at various levels')

# %% [markdown]
# ### Task 7: Find the co-relation between factors on affecting the GDP of India

# %%
analysis_india=data_india.copy()

# %%
analysis_gdp_edu=['NY.GDP.PCAP.PP.CD','SP.POP.GROW','BAR.NOED.2024.ZS','BAR.NOED.2529.ZS','BAR.NOED.3034.ZS','BAR.NOED.3539.ZS','IT.NET.USER.P2','IT.CMP.PCMP.P2']

# %%
for index,row in analysis_india.iterrows():
  if row['Indicator Code'] in (analysis_gdp_edu):
    pass
  else:
    analysis_india.drop(index,inplace=True)

# %%
analysis_india.head()
# Out:
#        Country Name Country Code  \
# 414533        India          IND
# 414547        India          IND
# 414554        India          IND
# 414561        India          IND
# 415392        India          IND
#
#                                            Indicator Name     Indicator Code  \
# 414533  Barro-Lee: Percentage of population age 20-24 ...   BAR.NOED.2024.ZS
# 414547  Barro-Lee: Percentage of population age 25-29 ...   BAR.NOED.2529.ZS
# 414554  Barro-Lee: Percentage of population age 30-34 ...   BAR.NOED.3034.ZS
# 414561  Barro-Lee: Percentage of population age 35-39 ...   BAR.NOED.3539.ZS
# 415392      GDP per capita, PPP (current international $)  NY.GDP.PCAP.PP.CD
#
#                2000        2002         2004         2006         2008  \
# 414533    29.500000    23.83000    23.830000     9.050000     9.050000
# 414547    36.370000    29.50000    29.500000    23.830000    23.830000
# 414554    43.120000    36.37000    36.370000    29.500000    29.500000
# ...

# %%
analysis_india.drop(['Country Name','Country Code','Indicator Code'],axis=1,inplace=True)
analysis_india.set_index('Indicator Name',inplace=True)

# %%
analysis_india=analysis_india.transpose()

# %%
sns.heatmap(analysis_india.corr(), cmap="Spectral",vmin=-1,vmax=1,linewidth=0.5, linecolor='black',annot=True)

# %% [markdown]
# # **SECTION -"C"** : *At this time we are totally conceptual to the all data. so we decided to find some more interesting anlyse view point just like now we will try to do Comparing India with neighboring countries in Gross Enrolment Ratio (2010), Variation in performance of Females and Males in PISA and TIMSS*

# %% [markdown]
# ### Since 2010 has most amount of data about the indicators, Now let's look at the spread of data across various regions. we saw this in section 'A' when we were exploring data

# %%
df1 = pd.merge(df_data, df_country[['Country Code', 'Region', 'Income Group', 'Special Notes']], how = 'left', on = 'Country Code').reset_index(drop=True)
df1.shape
# Out:
# (886930, 73)

# %%
df2 = df1[~df1['Region'].isna()]

# %% [markdown]
# ## TASK1: Comparing India with neighboring countries - Pakistan, Nepal, Bhutan, China, Sri Lanka in Gross Enrolment Ratio **(2010)**
#
# * **Gross Enrolement Ratio** = Total enrollment in pre-primary education, regardless of age, expressed as a percentage of the total population of official pre-primary education age.

# %%
# Subset
ctr_df = data_copy.loc[df_data['Country Code'].isin(['IND', 'NPL', 'PAK', 'CHN', 'BGD'])][['Country Name', 'Indicator Name', '2010']]


# filter for Indicators
list1 = ['Gross enrolment ratio, lower secondary, both sexes (%)', 'Gross enrolment ratio, primary, both sexes (%)', 'Gross enrolment ratio, secondary, both sexes (%)', 
         'Gross enrolment ratio, upper secondary, both sexes (%)']
filter1 = ctr_df.loc[ctr_df['Indicator Name'].isin(list1)]

# %%
filter2 = filter1.pivot(index='Indicator Name', columns='Country Name', values='2010').reset_index()
filter2['Levels'] = ['lower secondary', 'primary', 'secondary', 'upper secondary']
filter2
# Out:
# Country Name                                     Indicator Name  Bangladesh  \
# 0             Gross enrolment ratio, lower secondary, both s...   64.591141
# 1                Gross enrolment ratio, primary, both sexes (%)  102.656288
# 2              Gross enrolment ratio, secondary, both sexes (%)   50.119419
# 3             Gross enrolment ratio, upper secondary, both s...   39.382790
#
# Country Name       China       India       Nepal   Pakistan           Levels
# 0             103.071503   80.176369   77.193901  46.820122  lower secondary
# 1             112.473923  109.183647  142.285446  95.740982          primary
# 2              84.921158   63.290939   58.793621  35.848461        secondary
# 3              69.903603   50.259708   43.521389  27.357670  upper secondary

# %%
# Plot for Gross Enrollment Ratio across all these countries
labels = list(filter2['Levels'])
Bangladesh = list(filter2['Bangladesh'])
China = list(filter2['China'])
India = list(filter2['India'])
Nepal = list(filter2['Nepal'])
Pakistan = list(filter2['Pakistan'])

x = np.arange(len(labels))  # the label locations
width = 0.15  # the width of the bars

fig, ax = plt.subplots(figsize=(15, 8))
rects1 = ax.bar(x+width, Bangladesh, width, label='Bangladesh')
rects2 = ax.bar(x+2*width, China, width, label='China')
rects3 = ax.bar(x+3*width, India, width, label='India')
rects4 = ax.bar(x+4*width, Nepal, width, label='Nepal')
rects5 = ax.bar(x+5*width, Pakistan, width, label='Pakistan')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Gross Enrolment Ratio')
ax.set_title('Gross Enrolment Ratio for 2010', fontsize=20)
ax.set_xticks(x+0.4)
ax.set_xticklabels(labels)
ax.legend()


fig.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# ## TASK2: Variation in performance of Females and Males in PISA and TIMSS across years - for PISA - from 2000 to 2015; for TIMSS take 1995 - 2015 - consider only participating countries; data not available for all countries
#
# **PISA:**
# The Program for International Student Assessment (PISA) is an international assessment that measures 15-year-old students' reading, mathematics, and science, literacy measured every three years.
#
# **TIMSS:** The Trends in International Mathematics and Science Study (TIMSS) provides reliable and timely trend data on the mathematics and science achievement of U.S. students compared to that of students in other countries.

# %%
# List of relevant PISA indicators
list_PISA = ['PISA: Mean performance on the mathematics scale. Female', 'PISA: Mean performance on the mathematics scale. Male', 
        'PISA: Mean performance on the reading scale. Female', 'PISA: Mean performance on the reading scale. Male', 
        'PISA: Mean performance on the science scale. Female', 'PISA: Mean performance on the science scale. Male']

filter_pisa = df2[df2['Indicator Name'].isin(list_PISA)]
filter_pisa = filter_pisa.drop(['Country Code', 'Indicator Code', 'Special Notes', 'Region'], axis = 1)

# %%
# Dropping specific null values without losing relevant data
temp_a = filter_pisa[~filter_pisa['2015'].isna()].reset_index(drop=True)
temp_b = temp_a[~temp_a['2012'].isna()].reset_index(drop=True)
temp_c = temp_b[~temp_b['2009'].isna()].reset_index(drop=True)
temp_d = temp_c[~temp_c['2006'].isna()].reset_index(drop=True)
temp_e = temp_d[~temp_d['2003'].isna()].reset_index(drop=True)
temp_f = temp_e[~temp_e['2000'].isna()].reset_index(drop=True)
temp_f.shape
# Out:
# (196, 69)

# %%
PISA=temp_f.drop(['2001', '2002', '2004', '2005', '2007', '2008', '2010', '2011', '2013', '2014'], axis=1)
PISA['Income Group'].unique()
# Out:
# array(['High income: OECD', 'Upper middle income', 'High income: nonOECD',
#        'Lower middle income'], dtype=object)

# %%
a1 = PISA[['Income Group', 'Country Name']].drop_duplicates().reset_index(drop=True)
a2 = pd.DataFrame(a1.groupby('Income Group')['Country Name'].count()).reset_index()

# %%
# Bar plot for no. of countries across income levels
sns.set_theme()
fig, ax = plt.subplots(figsize=(8,6))
colors = sns.color_palette("muted")
ax = sns.barplot(x='Income Group', y='Country Name', palette=colors, data=a2)
ax.set(xlabel='Income Group',ylabel='No. of countries')
ax.set_title('No. of participating countries in Pissa with available data', fontsize = 16)
plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
plt.show()

# %% [markdown]
# ###**Let's look at PISA performance across genders.**

# %%
# Adding new columns to PISA df
PISA['gender'] = np.where(PISA['Indicator Name'].str.contains('Female'), 'female', 'male')
PISA['subject'] = np.where(PISA['Indicator Name'].str.contains('mathematics'), 'mathematics', np.where(PISA['Indicator Name'].str.contains('reading'), 'reading', 'science'))

# %%
pd.options.display.max_colwidth = 100
PISA[['Indicator Name', 'subject', 'gender']].drop_duplicates()
# Out:
#                                             Indicator Name      subject  \
# 0  PISA: Mean performance on the mathematics scale. Female  mathematics
# 1    PISA: Mean performance on the mathematics scale. Male  mathematics
# 2      PISA: Mean performance on the reading scale. Female      reading
# 3        PISA: Mean performance on the reading scale. Male      reading
# 4      PISA: Mean performance on the science scale. Female      science
# 5        PISA: Mean performance on the science scale. Male      science
#
#    gender
# 0  female
# 1    male
# 2  female
# 3    male
# 4  female
# 5    male

# %%
#Plotting avg PISA scores for male and female for various subjects
math =  PISA[PISA['subject']=='mathematics'].drop(['Indicator Name','Country Name', 'Income Group', 'subject'], axis=1)
math1 = math.groupby('gender').mean().T

science =  PISA[PISA['subject']=='science'].drop(['Indicator Name','Country Name', 'Income Group', 'subject'], axis=1)
science1 = science.groupby('gender').mean().T

reading =  PISA[PISA['subject']=='reading'].drop(['Indicator Name','Country Name', 'Income Group', 'subject'], axis=1)
reading1 = reading.groupby('gender').mean().T

fig, axes = plt.subplots(1,3, figsize=(20, 5))

plt.suptitle('Average PISA scores - Male and Female')

sns.lineplot(ax=axes[0], data=math1)
sns.lineplot(ax=axes[1], data=science1)
sns.lineplot(ax=axes[2], data=reading1)

axes[0].set_title("Mean Score across Years - PISA Mathematics")
axes[1].set_title("Mean Score across Years - PISA Science")
axes[2].set_title("Mean Score across Years - PISA Reading")

plt.show()

# %%
list4 = ['PISA: Mean performance on the mathematics scale', 'PISA: Mean performance on the reading scale', 'PISA: Mean performance on the science scale']

filter1 = df2[df2['Indicator Name'].isin(list4)]
filter2 = filter1.drop(['Country Code', 'Indicator Code', 'Special Notes', 'Region'], axis=1)

a = filter2[~filter2['2015'].isna()].reset_index(drop=True)
b = a[~a['2012'].isna()].reset_index(drop=True)
c = b[~b['2009'].isna()].reset_index(drop=True)
d = c[~c['2006'].isna()].reset_index(drop=True)
e = d[~d['2003'].isna()].reset_index(drop=True)
f = e[~e['2000'].isna()].reset_index(drop=True)
f.shape

PISA=f.drop(['2001', '2002', '2004', '2005', '2007', '2008', '2010', '2011', '2013', '2014'], axis=1)

PISA['subject'] = np.where(PISA['Indicator Name'].str.contains('mathematics'), 'mathematics', np.where(PISA['Indicator Name'].str.contains('reading'), 'reading', 'science'))

# %%
PISA1 = PISA[['Country Name', 'subject', '2015']]
math = PISA1[PISA1['subject']=='mathematics'].sort_values(by='2015', ascending=False)
science = PISA1[PISA1['subject']=='science'].sort_values(by='2015', ascending=False)
reading = PISA1[PISA1['subject']=='reading'].sort_values(by='2015', ascending=False)

# %%
sns.set_theme()
fig, axes = plt.subplots(1,2, figsize=(20, 5))
colors = sns.color_palette("muted")

plt.suptitle('Top 10 and Bottom 10 Countires based on Mathematics Performance in PISA')

fig1 = sns.barplot(ax=axes[0], x='Country Name', y='2015', palette=colors, data=math[:10])
fig2 = sns.barplot(ax=axes[1], x='Country Name', y='2015', palette=colors, data=math[-10:])

axes[0].set_title("Top 10 Countries")
axes[1].set_title("Bottom 10 Countries")

plt.setp(fig1.get_xticklabels(), rotation=35, horizontalalignment='right')
plt.setp(fig2.get_xticklabels(), rotation=35, horizontalalignment='right')

plt.show()

# %%
sns.set_theme()
fig, axes = plt.subplots(1,2, figsize=(20, 5))
colors = sns.color_palette("muted")

plt.suptitle('Top 10 and Bottom 10 Countires based on Science Performance in PISA')

fig1 = sns.barplot(ax=axes[0], x='Country Name', y='2015', palette=colors, data=science[:10])
fig2 = sns.barplot(ax=axes[1], x='Country Name', y='2015', palette=colors, data=science[-10:])

axes[0].set_title("Top 10 Countries")
axes[1].set_title("Bottom 10 Countries")

plt.setp(fig1.get_xticklabels(), rotation=35, horizontalalignment='right')
plt.setp(fig2.get_xticklabels(), rotation=35, horizontalalignment='right')

plt.show()

# %%
list5 = ['TIMSS: Mean performance on the mathematics scale for fourth grade students, total', 'TIMSS: Mean performance on the mathematics scale for eighth grade students, total',
        'TIMSS: Mean performance on the science scale for fourth grade students, total', 'TIMSS: Mean performance on the science scale for eighth grade students, total']

filter1 = df2[df2['Indicator Name'].isin(list5)]
filter2 = filter1[['Country Name', 'Indicator Name', '2015']].dropna()
filter3 = filter1[['Income Group', 'Indicator Name', '2015']].dropna()
filter2['subject'] = np.where(filter2['Indicator Name'].str.contains('mathematics'), 'mathematics', 'science')
filter2['grade'] = np.where(filter2['Indicator Name'].str.contains('eighth'), 'eight', 'four')
math = filter2[filter2['subject']=='mathematics'].sort_values(by='2015', ascending=False)
math4 = math[math['grade']=='four'].sort_values(by='2015', ascending=False)
math8 = math[math['grade']=='eight'].sort_values(by='2015', ascending=False)
science = filter2[filter2['subject']=='science'].sort_values(by='2015', ascending=False)
science4 = science[science['grade']=='four'].sort_values(by='2015', ascending=False)
science8 = science[science['grade']=='eight'].sort_values(by='2015', ascending=False)

# %%
a1 = filter1[['Income Group', 'Country Name']].drop_duplicates().reset_index(drop=True)
a2 = pd.DataFrame(a1.groupby('Income Group')['Country Name'].count()).reset_index()

sns.set_theme()
fig, ax = plt.subplots(figsize=(8,6))
colors = sns.color_palette("muted")
ax = sns.barplot(x='Income Group', y='Country Name', palette=colors, data=a2)
ax.set(xlabel='Income Group',ylabel='No. of countries')
ax.set_title('No. of participating countries in Timss with available data', fontsize = 16)
plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
plt.show()

# %% [markdown]
# ### TIMSS data is available only for 4th grade and 8th grade, but since we considered PISA, which is take for students aged 15, we considered TIMSS data for fourth graders alone.

# %%
sns.set_theme()
fig, axes = plt.subplots(1,2, figsize=(20, 5))
colors = sns.color_palette("muted")

plt.suptitle('Top 10 and Bottom 10 Countires based on Mathematics Performance fourth grade in TIMSS')

fig1 = sns.barplot(ax=axes[0], x='Country Name', y='2015', palette=colors, data=math4[:10])
fig2 = sns.barplot(ax=axes[1], x='Country Name', y='2015', palette=colors, data=math4[-10:])

axes[0].set_title("Top 10 Countries")
axes[1].set_title("Bottom 10 Countries")

plt.setp(fig1.get_xticklabels(), rotation=35, horizontalalignment='right')
plt.setp(fig2.get_xticklabels(), rotation=35, horizontalalignment='right')

plt.show()

# %%
sns.set_theme()
fig, axes = plt.subplots(1,2, figsize=(20, 5))
colors = sns.color_palette("muted")

plt.suptitle('Top 10 and Bottom 10 Countires based on Science Performance fourth grade in TIMSS')

fig1 = sns.barplot(ax=axes[0], x='Country Name', y='2015', palette=colors, data=science4[:10])
fig2 = sns.barplot(ax=axes[1], x='Country Name', y='2015', palette=colors, data=science4[-10:])

axes[0].set_title("Top 10 Countries")
axes[1].set_title("Bottom 10 Countries")

plt.setp(fig1.get_xticklabels(), rotation=35, horizontalalignment='right')
plt.setp(fig2.get_xticklabels(), rotation=35, horizontalalignment='right')

plt.show()

# %% [markdown]
# # **Final Conclusion :**
#
# 1) This study shows that most of the countries, whether developed and   developing, are part of the World Bank, that's why the region with a high number of countries has high involvement.
#
# 2)The population growth analysis, based on income, indicates that the country's government of low, middle wages should implement some laws to control the  population growth.
#
# 3)GDP bars show that highly developed countries have GDP exceeding 120000 and  top developing countries have GDP exceeding 12000. This indicates a very vast difference in terms of economics of the country.
#
# 4)Education analysis of the youth shows that literacy rate is increasing over the years but still females are lacking behind compared to the total population literacy. Government and individuals should pay attention to education.
#
# 5)Literacy rate and technical advancement, directly influencing the GDP of the Country, should be increased.
#
# 6)PISS and TIMSS analysis show that it's quite different for male and females in the Mathematics and Reading field.
